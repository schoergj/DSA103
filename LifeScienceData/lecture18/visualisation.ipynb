# %% [markdown]
# # Visualisation — Matplotlib and Seaborn Fundamentals
# This notebook will introduce the basic functions of matplotlib and seaborn (which is built on matplotlib). The data used is mostly synthetic, with the exception of the wine-dataset used in one part (imported from sklearn)

# %%
# Cell 1: Imports and plotting defaults
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import datasets

# %%
# plotting defaults for a presentation
# explore on the first graph how the plot changes when you switch the context to e.g. "paper" or "poster"
sns.set_theme(style='whitegrid', context='talk')
plt.rcParams['figure.dpi'] = 120

RNG = np.random.default_rng(0)  # reproducible RNG

# load generated dataset
enzyme_kinetics_df = pd.read_csv("enzyme_kinetics_df.csv")
enzyme_kinetics_df.head()
# Out:
#      enzyme  replicate  substrate_mM       rate
# 0  Enzyme_1          1      0.010000  -5.438464
# 1  Enzyme_1          1      0.050000        NaN
# 2  Enzyme_1          1      0.772727  28.823510
# 3  Enzyme_1          1      0.918182  29.049695
# 4  Enzyme_1          1      1.495455  42.965803

# %% [markdown]
# ### Plot: scatter + mean line with confidence band
# Demonstrate: axes labels, units, legend, error band (seaborn lineplot `errorbar`).

# %%
# Scatter + mean trend with uncertainty
plt.figure(figsize=(8,5))
sns.scatterplot(data=enzyme_kinetics_df, x='substrate_mM', y='rate', hue='enzyme', alpha=0.6)
sns.lineplot(data=enzyme_kinetics_df, x='substrate_mM', y='rate', hue='enzyme', estimator='mean', errorbar='sd', lw=2)
plt.xscale('linear')
plt.xlabel('Substrate concentration [mM]')
plt.ylabel('Reaction rate [µmol/min]')
plt.title('Enzyme kinetics — replicates & mean ± SD')
plt.legend(title='Enzyme')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### STUDENT TASK 1 (short)
# - Replot the enzyme kinetics for each enzyme separately using `sns.FacetGrid` or `sns.relplot` with facet columns.
# - Try `estimator='median'` and compare the median and mean curves. Comment: when is median more robust?

# %%
relplot = sns.relplot(data=enzyme_kinetics_df, x='substrate_mM', y='rate',
                col='enzyme', kind='line', estimator='mean', errorbar=('sd'), height=4, aspect=1.1)
relplot.set_axis_labels('Substrate concentration [mM]', 'Reaction rate [µmol/min]')
relplot.figure.suptitle('Enzyme kinetics', y=1.02)
plt.show()

# %% [markdown]
# ## Protein melting curve

# %%
protein_melting_df = pd.read_csv("protein_melting.csv")
protein_melting_df.head()
# Out:
#   protein  replicate     temp_C  fluorescence
# 0      WT          1  20.000000     16.266044
# 1      WT          1  22.586207     12.413287
# 2      WT          1  25.172414     15.946751
# 3      WT          1  27.758621     18.601542
# 4      WT          1  30.344828     18.847755

# %% [markdown]
# ### Plot: multiple replicates (small multiples) and mean curve per protein
# Show case for faceting & shaded CI.

# %%
# Cell 5: Faceted line plots with CI
g = sns.relplot(data=protein_melting_df, x='temp_C', y='fluorescence',
                col='protein', kind='line', estimator='mean', errorbar=('ci',68), height=4, aspect=1.1)
g.set_axis_labels('Temperature (°C)', 'Fluorescence (a.u.)')
g.figure.suptitle('Protein melting curves (mean ± 68% CI)', y=1.02)
plt.show()

# %%
# Cell 6: Matplotlib example with custom styling and export
fig, ax = plt.subplots(figsize=(6.5,4))
# plot WT melting curves with semi-transparent replicates
subset = protein_melting_df[protein_melting_df['protein'] == 'WT']
sns.lineplot(data=subset, x='temp_C', y='fluorescence', hue='replicate', estimator=None, alpha=0.4, legend=False, ax=ax)
# overlay mean curve
sns.lineplot(data=subset, x='temp_C', y='fluorescence', estimator='mean', errorbar='sd', lw=2.5, ax=ax, color='black')
ax.set_xlabel('Temperature (°C)')
ax.set_ylabel('Fluorescence (a.u.)')
ax.set_title('WT protein melting — replicates + mean ± SD')
ax.text(0.02, 0.95, 'Instructor note: shaded band = ±1 SD', transform=ax.transAxes, fontsize=10, va='top')
fig.tight_layout()
# Save as PDF suitable for publication
plt.savefig('WT_melting_example.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### STUDENT TASK 2
# - Export the figure as an SVG and PNG. Compare file sizes and when to use vector (SVG/PDF) vs raster (PNG).
# - Add axis ticks with scientific notation for the rate axis if values are large.

# %% [markdown]
# ## 3. Distribution plots & comparisons
# Boxplot vs violin vs histogram — how to choose.

# %%
# Cell 7: Distribution comparisons using wine dataset
wine = datasets.load_wine(as_frame=True)
wine_df = wine.frame
wine_df['target'] = wine_df['target'].astype('category')  # convert to categorical
# Quick example: compare 'alcohol' distribution by class
plt.figure(figsize=(8,4))
sns.boxplot(data=wine_df, x='target', y='alcohol')
sns.stripplot(data=wine_df, x='target', y='alcohol', color='k', alpha=0.4, jitter=0.2)
plt.xlabel('Wine class (target)')
plt.ylabel('Alcohol (%)')
plt.title('Alcohol distribution by wine class (box + jittered points)')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 8
#       6 plt.figure(figsize=(8,4))
#       7 sns.boxplot(data=wine_df, x='target', y='alcohol')
# ----> 8 sns.stripplot(data=wine_df, x='target', y='alcohol', color='j', alpha=0.4, jitter=0.2)
#       9 plt.xlabel('Wine class (target)')
#      10 plt.ylabel('Alcohol (%)')
#
# File c:\Users\jschoer\Desktop\DSA103 Coding and Tests\DSA103\LifeScienceData\.venv\Lib\site-packages\seaborn\categorical.py:2108, in stripplot(data, x, y, hue, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2106 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    2107 color = _default_color(ax.scatter, hue, color, kwargs)
# -> 2108 edgecolor = p._complement_color(edgecolor, color, p._hue_map)
#    2110 kwargs.setdefault("zorder", 3)
#    2111 size = kwargs.get("s", size)
#
# File c:\Users\jschoer\Desktop\DSA103 Coding and Tests\DSA103\LifeScienceData\.venv\Lib\site-packages\seaborn\categorical.py:330, in _CategoricalPlotter._complement_color(self, color, base_color, hue_map)
#     328     if base_color is None:
#     329         return None
# --> 330     basis = [mpl.colors.to_rgb(base_color)]
#     331 else:
#     332     basis = [mpl.colors.to_rgb(c) for c in hue_map.lookup_table.values()]
#
# File c:\Users\jschoer\Desktop\DSA103 Coding and Tests\DSA103\LifeScienceData\.venv\Lib\site-packages\matplotlib\colors.py:529, in to_rgb(c)
#     527 def to_rgb(c):
#     528     """Convert *c* to an RGB color, silently dropping the alpha channel."""
# --> 529     return to_rgba(c)[:3]
#
# File c:\Users\jschoer\Desktop\DSA103 Coding and Tests\DSA103\LifeScienceData\.venv\Lib\site-packages\matplotlib\colors.py:317, in to_rgba(c, alpha)
#     315     rgba = None
#     316 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 317     rgba = _to_rgba_no_colorcycle(c, alpha)
#     318     try:
#     319         _colors_full_map.cache[c, alpha] = rgba
#
# File c:\Users\jschoer\Desktop\DSA103 Coding and Tests\DSA103\LifeScienceData\.venv\Lib\site-packages\matplotlib\colors.py:394, in _to_rgba_no_colorcycle(c, alpha)
#     390             raise ValueError(
#     391                 f"Invalid string grayscale value {orig_c!r}. "
#     392                 f"Value must be within 0-1 range")
#     393         return c, c, c, alpha if alpha is not None else 1.
# --> 394     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     395 # turn 2-D array into 1-D array
#     396 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: 'j'

# %% [markdown]
# ### STUDENT TASK 3
# - Recreate the same comparison using `sns.violinplot`. Which visual conveys sample skew or multimodality better?
# - For `alcohol`, produce a histogram and a KDE (kernel density estimate). Discuss bandwidth impact.

# %% [markdown]
# ## 4. Color & accessibility
# - Use `viridis`, `cividis`, or `sns.color_palette("colorblind")` for accessible palettes.
# - Avoid rainbow colormaps for continuous quantitative scales.

# %%
# Cell 8: Color palette examples
pal = sns.color_palette("colorblind")
sns.palplot(pal)
plt.title('Colorblind-friendly palette')
plt.show()

# Example: choose sequential colormap for heatmap
sample_corr = wine_df.select_dtypes(include=[np.number]).corr()
plt.figure(figsize=(12,10))
sns.heatmap(sample_corr, cmap='vlag', center=0, linewidths=0.5)
plt.title('Correlation matrix — example')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Final short exercise and wrap-up
# Students prepare one plot from either enzyme_kinetics_df or protein_melting_df applying:
# - good labels, units
# - accessible colors
# - a short caption (1–2 sentences) explaining what the plot shows
