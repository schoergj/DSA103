# %%
import pandas as pd
import numpy as np

# %%
df_raw = pd.read_csv("ChEMBL_EColi_MICs_raw.csv", delimiter=";")
df_raw.head()
# Out:
#   Molecule ChEMBL ID       Molecule Name  Molecule Max Phase  \
# 0          CHEMBL148  IMIPENEM ANHYDROUS                 4.0
# 1          CHEMBL148  IMIPENEM ANHYDROUS                 4.0
# 2            CHEMBL5      NALIDIXIC ACID                 4.0
# 3      CHEMBL1163694                 NaN                 NaN
# 4      CHEMBL1164148                 NaN                 NaN
#
#    Molecular Weight  #RO5 Violations  AlogP    Compound Key  \
# 0            299.35              0.0  -0.18             IPM
# 1            299.35              0.0  -0.18             IPM
# 2            232.24              0.0   1.42  Nalidixic acid
# 3            265.36              0.0   3.47               4
# 4            249.29              0.0   2.75              25
#
#                                               Smiles Standard Type  \
# 0  C[C@@H](O)[C@H]1C(=O)N2C(C(=O)O)=C(SCCNC=N)C[C...           MIC
# 1  C[C@@H](O)[C@H]1C(=O)N2C(C(=O)O)=C(SCCNC=N)C[C...           MIC
# ...

# %%
df_raw.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties',
# ...

# %%
df_select = df_raw[['Molecule ChEMBL ID', 'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
       'Standard Units', 'Assay ChEMBL ID']]
df_select.head()
# Out:
#   Molecule ChEMBL ID                                             Smiles  \
# 0          CHEMBL148  C[C@@H](O)[C@H]1C(=O)N2C(C(=O)O)=C(SCCNC=N)C[C...
# 1          CHEMBL148  C[C@@H](O)[C@H]1C(=O)N2C(C(=O)O)=C(SCCNC=N)C[C...
# 2            CHEMBL5                    CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21
# 3      CHEMBL1163694                        CCOC(=O)/C=C\Sc1nc2ccccc2s1
# 4      CHEMBL1164148                        CCOC(=O)/C=C\Oc1nc2ccccc2s1
#
#   Standard Type Standard Relation  Standard Value Standard Units  \
# 0           MIC               '='            0.25        ug.mL-1
# 1           MIC               '='            0.25        ug.mL-1
# 2           MIC               '='          256.00        ug.mL-1
# 3           MIC               '>'          128.00        ug.mL-1
# 4           MIC               '>'          128.00        ug.mL-1
#
#   Assay ChEMBL ID
# 0    CHEMBL918742
# 1    CHEMBL918170
# 2    CHEMBL916555
# 3   CHEMBL1167747
# 4   CHEMBL1167747

# %%
new_names = ["molecule_chembl_id", "canonical_smiles", "standard_type", "standard_relation", "standard_value", "standard_units", "assay_chembl_id"]
df_select.columns = new_names
df_select.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL148  C[C@@H](O)[C@H]1C(=O)N2C(C(=O)O)=C(SCCNC=N)C[C...
# 1          CHEMBL148  C[C@@H](O)[C@H]1C(=O)N2C(C(=O)O)=C(SCCNC=N)C[C...
# 2            CHEMBL5                    CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21
# 3      CHEMBL1163694                        CCOC(=O)/C=C\Sc1nc2ccccc2s1
# 4      CHEMBL1164148                        CCOC(=O)/C=C\Oc1nc2ccccc2s1
#
#   standard_type standard_relation  standard_value standard_units  \
# 0           MIC               '='            0.25        ug.mL-1
# 1           MIC               '='            0.25        ug.mL-1
# 2           MIC               '='          256.00        ug.mL-1
# 3           MIC               '>'          128.00        ug.mL-1
# 4           MIC               '>'          128.00        ug.mL-1
#
#   assay_chembl_id
# 0    CHEMBL918742
# 1    CHEMBL918170
# 2    CHEMBL916555
# 3   CHEMBL1167747
# 4   CHEMBL1167747

# %%
df_sample = df_select.sample(n=300, random_state=42)
df_sample
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 6054      CHEMBL3621433                    Cc1ccc(N(CC#N)Cc2ccc(F)cc2F)cc1
# 5556      CHEMBL4450418  N#C[C@@H]1CC[C@@H]2CN1C(=O)N2OS(=O)(=O)[O-].[Na+]
# 8332      CHEMBL2236659                 O=C(/C=C/c1c(Cl)cccc1Cl)c1ccc[nH]1
# 7672      CHEMBL4127175                 OB(O)c1ccc(Cn2cc(-c3ccccn3)nn2)cc1
# 3319       CHEMBL296800                COc1cc2oc(-c3ccccc3)cc(=O)c2c(O)c1O
# ...                 ...                                                ...
# 7763      CHEMBL5177243            CNC1=NC(=O)C(C(C)c2c[nH]c3c(F)cccc23)O1
# 6224      CHEMBL3221106                      C#CCOc1ccc(OCC=C)c(C(=O)NO)c1
# 1323           CHEMBL22                    COc1cc(Cc2cnc(N)nc2N)cc(OC)c1OC
# 4279      CHEMBL1455814                      COc1ccc2[nH]c(-c3ccccc3)nc2c1
# 3742          CHEMBL148  C[C@@H](O)[C@H]1C(=O)N2C(C(=O)O)=C(SCCNC=N)C[C...
#
# ...

# %%
df_sample.to_csv("ecoli_mics.csv", index=False)
